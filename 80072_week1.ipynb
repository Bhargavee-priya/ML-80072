# %%
print ("hellow world")
# Out:
# hellow world

# %%
n = "ammu"
b = 19
print("n is " + str(type(n)))
print("b is " + str(type(b)))
# Out:
# n is <class 'str'>
# b is <class 'int'>

# %%
n = 19
print(n,",",type(n))
# Out:
# 19 , <class 'int'>

# %%
a,b,c = 1,2,3
p=q=r=5
print(a,b,c)
print(p)
print(q)
print(r)
# Out:
# 1 2 3
# 5
# 5
# 5

# %%
n = ["apple","banana","mango","grape"]
print(n)
# Out:
# ['apple', 'banana', 'mango', 'grape']

# %%
n = {"mahindra thar","180","2023"}
print(n)
# Out:
# {'180', 'mahindra thar', '2023'}
